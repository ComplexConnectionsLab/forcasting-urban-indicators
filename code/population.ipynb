# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from os import listdir

# %%
pop_00_10 = pd.read_excel("../data/raw/pop/2000-2010/co-est00int-01-01.xls")
pop_00_10
# Out:
#    table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0   Table 1. Intercensal Estimates of the Resident...
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                             Alabama
# 4                                     .Autauga County
# ..                                                ...
# 74  Note: All geographic boundaries for the 2000-2...
# 75                                Suggested Citation:
# 76  Table 1. Intercensal Estimates of the Resident...
# 77    Source: U.S. Census Bureau, Population Division
# 78                       Release Date: September 2011
#
#         Unnamed: 1                            Unnamed: 2  Unnamed: 3  \
# 0              NaN                                   NaN         NaN
# 1   April 1, 20001  Intercensal Estimates (as of July 1)         NaN
# ...

# %%
pop_00_10=pop_00_10.iloc[1:pop_00_10.shape[0]-8]
#.drop([0, 71, 72,73,74,75,76,77,78], axis=0, inplace=True)
pop_00_10
# Out:
#    table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 1                                     Geographic Area
# 2                                                 NaN
# 3                                             Alabama
# 4                                     .Autauga County
# 5                                     .Baldwin County
# ..                                                ...
# 66                                 .Tuscaloosa County
# 67                                     .Walker County
# 68                                 .Washington County
# 69                                     .Wilcox County
# 70                                    .Winston County
#
#         Unnamed: 1                            Unnamed: 2  Unnamed: 3  \
# 1   April 1, 20001  Intercensal Estimates (as of July 1)         NaN
# 2              NaN                                  2000      2001.0
# ...

# %%
pop_00_10 = pop_00_10.iloc[2:]
pop_00_10
# Out:
#    table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 3                                             Alabama
# 4                                     .Autauga County
# 5                                     .Baldwin County
# 6                                     .Barbour County
# 7                                        .Bibb County
# ..                                                ...
# 66                                 .Tuscaloosa County
# 67                                     .Walker County
# 68                                 .Washington County
# 69                                     .Wilcox County
# 70                                    .Winston County
#
#    Unnamed: 1 Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 3     4447207    4452173   4467634.0   4480089.0   4503491.0   4530729.0
# 4       43751      44021     44889.0     45909.0     46800.0     48366.0
# ...

# %%
pop_00_10.columns = ["Geographic Area", "April 1, 2000", "2000", "2001", "2002", "2003", "2004", "2005", 
                     "2006", "2007", "2008", "2009", "April 1, 2010", "July 1, 2010"]
pop_00_10
# Out:
#        Geographic Area April 1, 2000     2000       2001       2002  \
# 3              Alabama       4447207  4452173  4467634.0  4480089.0
# 4      .Autauga County         43751    44021    44889.0    45909.0
# 5      .Baldwin County        140416   141342   144875.0   147957.0
# 6      .Barbour County         29042    29015    28863.0    28653.0
# 7         .Bibb County         19856    19913    21028.0    21199.0
# ..                 ...           ...      ...        ...        ...
# 66  .Tuscaloosa County        164932   165414   166951.0   168154.0
# 67      .Walker County         70688    70602    70364.0    69765.0
# 68  .Washington County         18077    18101    17933.0    17895.0
# 69      .Wilcox County         12995    12939    12806.0    12778.0
# 70     .Winston County         24806    24857    24597.0    24600.0
#
#          2003       2004       2005       2006       2007       2008  \
# 3   4503491.0  4530729.0  4569805.0  4628981.0  4672840.0  4718206.0
# ...

# %%
def stripStop(x):
    return x.strip(".")

# %%
pops = {}
for file in listdir("../data/raw/pop/2000-2010/"):
    pops[file] = pd.read_excel(f"../data/raw/pop/2000-2010/{file}")
    pops[file] = pops[file].iloc[3:pops[file].shape[0]-8]
    pops[file].columns = ["Geographic Area", "April 1, 2000", "2000", "2001", "2002", "2003", "2004",
                          "2005", "2006", "2007", "2008", "2009", "April 1, 2010", "July 1, 2010"]
    state = pops[file]["Geographic Area"].iloc[0]
    pops[file] = pops[file].iloc[1:]
    pops[file]["Geographic Area"] += f", {state}"
    pops[file]["Geographic Area"] = pops[file]["Geographic Area"].apply(stripStop)

# %%
pops
# Out:
# {'co-est00int-01-01.xls':                Geographic Area April 1, 2000    2000      2001      2002  \
#  4      Autauga County, Alabama         43751   44021   44889.0   45909.0
#  5      Baldwin County, Alabama        140416  141342  144875.0  147957.0
#  6      Barbour County, Alabama         29042   29015   28863.0   28653.0
#  7         Bibb County, Alabama         19856   19913   21028.0   21199.0
#  8       Blount County, Alabama         50982   51107   51845.0   52551.0
#  ..                         ...           ...     ...       ...       ...
#  66  Tuscaloosa County, Alabama        164932  165414  166951.0  168154.0
#  67      Walker County, Alabama         70688   70602   70364.0   69765.0
#  68  Washington County, Alabama         18077   18101   17933.0   17895.0
#  69      Wilcox County, Alabama         12995   12939   12806.0   12778.0
#  70     Winston County, Alabama         24806   24857   24597.0   24600.0
#
# ...

# %%
counties = pd.concat(pops.values())
counties
# Out:
#                Geographic Area April 1, 2000    2000      2001      2002  \
# 4      Autauga County, Alabama         43751   44021   44889.0   45909.0
# 5      Baldwin County, Alabama        140416  141342  144875.0  147957.0
# 6      Barbour County, Alabama         29042   29015   28863.0   28653.0
# 7         Bibb County, Alabama         19856   19913   21028.0   21199.0
# 8       Blount County, Alabama         50982   51107   51845.0   52551.0
# ..                         ...           ...     ...       ...       ...
# 22  Sweetwater County, Wyoming         37620   37552   36899.0   37428.0
# 23       Teton County, Wyoming         18257   18381   18653.0   18837.0
# 24       Uinta County, Wyoming         19745   19666   19413.0   19587.0
# 25    Washakie County, Wyoming          8292    8252    8068.0    7988.0
# 26      Weston County, Wyoming          6643    6627    6487.0    6578.0
#
#         2003      2004      2005      2006      2007      2008      2009  \
# ...

# %%
counties.to_csv("../data/raw/pop/pop_2000_2010.csv")

# %%
pop_2010_2019 = pd.read_excel("../data/raw/pop/co-est2019-annres.xlsx")
pop_2010_2019
# Out:
#      table with row headers in column A and column headers in rows 3 through 4 (leading dots indicate sub-parts)  \
# 0     Annual Estimates of the Resident Population fo...
# 1                                       Geographic Area
# 2                                                   NaN
# 3                                         United States
# 4                              .Autauga County, Alabama
# ...                                                 ...
# 3147  Note: The 6,222 people in Bedford city, Virgin...
# 3148                                Suggested Citation:
# 3149  Annual Estimates of the Resident Population fo...
# 3150    Source: U.S. Census Bureau, Population Division
# 3151                           Release Date: March 2020
#
#                Unnamed: 1      Unnamed: 2                          Unnamed: 3  \
# 0                     NaN             NaN                                 NaN
# ...

# %%
cols = [pop_2010_2019.columns[0]] + [f"Unnamed: {i}" for i in range(3,13)]
pop_2010_2019 = pop_2010_2019.iloc[4:-6][cols]
pop_2010_2019.columns = ["Geographic Area"] + [str(i) for i in range(2010, 2020)]
pop_2010_2019
# Out:
#                   Geographic Area    2010      2011      2012      2013  \
# 4        .Autauga County, Alabama   54773   55227.0   54954.0   54727.0
# 5        .Baldwin County, Alabama  183112  186558.0  190145.0  194885.0
# 6        .Barbour County, Alabama   27327   27341.0   27169.0   26937.0
# 7           .Bibb County, Alabama   22870   22745.0   22667.0   22521.0
# 8         .Blount County, Alabama   57376   57560.0   57580.0   57619.0
# ...                           ...     ...       ...       ...       ...
# 3141  .Sweetwater County, Wyoming   43574   43986.0   45002.0   45157.0
# 3142       .Teton County, Wyoming   21296   21414.0   21624.0   22315.0
# 3143       .Uinta County, Wyoming   21089   20896.0   20996.0   20951.0
# 3144    .Washakie County, Wyoming    8530    8449.0    8409.0    8413.0
# 3145      .Weston County, Wyoming    7198    7142.0    7077.0    7136.0
#
#           2014      2015      2016      2017      2018      2019
# ...

# %%
pop_2010_2019[[str(i) for i in range(2010, 2020)]] = pop_2010_2019[[str(i) for i in range(2010, 2020)]].astype(np.int64)
pop_2010_2019
# Out:
#                   Geographic Area    2010    2011    2012    2013    2014  \
# 4        .Autauga County, Alabama   54773   55227   54954   54727   54893
# 5        .Baldwin County, Alabama  183112  186558  190145  194885  199183
# 6        .Barbour County, Alabama   27327   27341   27169   26937   26755
# 7           .Bibb County, Alabama   22870   22745   22667   22521   22553
# 8         .Blount County, Alabama   57376   57560   57580   57619   57526
# ...                           ...     ...     ...     ...     ...     ...
# 3141  .Sweetwater County, Wyoming   43574   43986   45002   45157   44948
# 3142       .Teton County, Wyoming   21296   21414   21624   22315   22773
# 3143       .Uinta County, Wyoming   21089   20896   20996   20951   20822
# 3144    .Washakie County, Wyoming    8530    8449    8409    8413    8273
# 3145      .Weston County, Wyoming    7198    7142    7077    7136    7138
#
#         2015    2016    2017    2018    2019
# ...

# %%
pop_2010_2019["Geographic Area"] = pop_2010_2019["Geographic Area"].apply(stripStop)
pop_2010_2019
# Out:
#                  Geographic Area    2010    2011    2012    2013    2014  \
# 4        Autauga County, Alabama   54773   55227   54954   54727   54893
# 5        Baldwin County, Alabama  183112  186558  190145  194885  199183
# 6        Barbour County, Alabama   27327   27341   27169   26937   26755
# 7           Bibb County, Alabama   22870   22745   22667   22521   22553
# 8         Blount County, Alabama   57376   57560   57580   57619   57526
# ...                          ...     ...     ...     ...     ...     ...
# 3141  Sweetwater County, Wyoming   43574   43986   45002   45157   44948
# 3142       Teton County, Wyoming   21296   21414   21624   22315   22773
# 3143       Uinta County, Wyoming   21089   20896   20996   20951   20822
# 3144    Washakie County, Wyoming    8530    8449    8409    8413    8273
# 3145      Weston County, Wyoming    7198    7142    7077    7136    7138
#
#         2015    2016    2017    2018    2019
# 4      54864   55243   55390   55533   55869
# ...

# %%
pop_2010_2019.to_csv("../data/raw/pop/pop_2010_2019.csv")

# %%
pop_2000_2010 = pd.read_csv("../data/raw/pop/pop_2000_2010.csv").rename(columns={"Geographic Area":"Area"})
pop_2000_2010.set_index("Area", inplace=True)
pop_2000_2010
# Out:
#                             Unnamed: 0  April 1, 2000    2000      2001  \
# Area
# Autauga County, Alabama              4          43751   44021   44889.0
# Baldwin County, Alabama              5         140416  141342  144875.0
# Barbour County, Alabama              6          29042   29015   28863.0
# Bibb County, Alabama                 7          19856   19913   21028.0
# Blount County, Alabama               8          50982   51107   51845.0
# ...                                ...            ...     ...       ...
# Sweetwater County, Wyoming          22          37620   37552   36899.0
# Teton County, Wyoming               23          18257   18381   18653.0
# Uinta County, Wyoming               24          19745   19666   19413.0
# Washakie County, Wyoming            25           8292    8252    8068.0
# Weston County, Wyoming              26           6643    6627    6487.0
#
#                                 2002      2003      2004      2005      2006  \
# Area
# ...

# %%
pop_2000_2010.drop(["Unnamed: 0"], axis=1, inplace=True)
pop_2000_2010
# Out:
#                             April 1, 2000    2000      2001      2002  \
# Area
# Autauga County, Alabama             43751   44021   44889.0   45909.0
# Baldwin County, Alabama            140416  141342  144875.0  147957.0
# Barbour County, Alabama             29042   29015   28863.0   28653.0
# Bibb County, Alabama                19856   19913   21028.0   21199.0
# Blount County, Alabama              50982   51107   51845.0   52551.0
# ...                                   ...     ...       ...       ...
# Sweetwater County, Wyoming          37620   37552   36899.0   37428.0
# Teton County, Wyoming               18257   18381   18653.0   18837.0
# Uinta County, Wyoming               19745   19666   19413.0   19587.0
# Washakie County, Wyoming             8292    8252    8068.0    7988.0
# Weston County, Wyoming               6643    6627    6487.0    6578.0
#
#                                 2003      2004      2005      2006      2007  \
# Area
# ...

# %%
pop_2010_2019 = pd.read_csv("../data/raw/pop/pop_2010_2019.csv").rename(columns={"Geographic Area":"Area"})
pop_2010_2019.set_index("Area", inplace=True)
pop_2010_2019.drop(["Unnamed: 0"], axis=1, inplace=True)
pop_2010_2019
# Out:
#                               2010    2011    2012    2013    2014    2015  \
# Area
# Autauga County, Alabama      54773   55227   54954   54727   54893   54864
# Baldwin County, Alabama     183112  186558  190145  194885  199183  202939
# Barbour County, Alabama      27327   27341   27169   26937   26755   26283
# Bibb County, Alabama         22870   22745   22667   22521   22553   22566
# Blount County, Alabama       57376   57560   57580   57619   57526   57526
# ...                            ...     ...     ...     ...     ...     ...
# Sweetwater County, Wyoming   43574   43986   45002   45157   44948   44719
# Teton County, Wyoming        21296   21414   21624   22315   22773   23047
# Uinta County, Wyoming        21089   20896   20996   20951   20822   20763
# Washakie County, Wyoming      8530    8449    8409    8413    8273    8278
# Weston County, Wyoming        7198    7142    7077    7136    7138    7208
#
#                               2016    2017    2018    2019
# ...
